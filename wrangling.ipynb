# %%
using Queryverse
using IndexedTables
using Statistics
using MLJ
using ShapML
using DataFrames

# %%
survey_data = Queryverse.load("multipleChoiceResponses.csv") |> 
    # Redundant first row
    @drop(1) |>
    DataFrame;

# %%
survey_data |> IndexedTables.table
# Out:
# Table with 23859 rows, 395 columns:
# Columns:
# #    colname                              type
# ────────────────────────────────────────────────
# 1    Time from Start to Finish (seconds)  String
# 2    Q1                                   String
# 3    Q1_OTHER_TEXT                        String
# 4    Q2                                   String
# 5    Q3                                   String
# 6    Q4                                   String
# 7    Q5                                   String
# 8    Q6                                   String
# 9    Q6_OTHER_TEXT                        String
# 10   Q7                                   String
# 11   Q7_OTHER_TEXT                        String
# 12   Q8                                   String
# 13   Q9                                   String
# 14   Q10                                  String
# 15   Q11_Part_1                           String
# 16   Q11_Part_2                           String
# 17   Q11_Part_3                           String
# 18   Q11_Part_4                           String
# 19   Q11_Part_5                           String
# 20   Q11_Part_6                           String
# 21   Q11_Part_7                           String
# 22   Q11_OTHER_TEXT                       String
# 23   Q12_MULTIPLE_CHOICE                  String
# 24   Q12_Part_1_TEXT                      String
# 25   Q12_Part_2_TEXT                      String
# 26   Q12_Part_3_TEXT                      String
# 27   Q12_Part_4_TEXT                      String
# 28   Q12_Part_5_TEXT                      String
# 29   Q12_OTHER_TEXT                       String
# 30   Q13_Part_1                           String
# 31   Q13_Part_2                           String
# 32   Q13_Part_3                           String
# 33   Q13_Part_4                           String
# 34   Q13_Part_5                           String
# 35   Q13_Part_6                           String
# 36   Q13_Part_7                           String
# 37   Q13_Part_8                           String
# 38   Q13_Part_9                           String
# 39   Q13_Part_10                          String
# 40   Q13_Part_11                          String
# 41   Q13_Part_12                          String
# 42   Q13_Part_13                          String
# 43   Q13_Part_14                          String
# 44   Q13_Part_15                          String
# 45   Q13_OTHER_TEXT                       String
# 46   Q14_Part_1                           String
# 47   Q14_Part_2                           String
# 48   Q14_Part_3                           String
# 49   Q14_Part_4                           String
# 50   Q14_Part_5                           String
# 51   Q14_Part_6                           String
# 52   Q14_Part_7                           String
# 53   Q14_Part_8                           String
# 54   Q14_Part_9                           String
# 55   Q14_Part_10                          String
# 56   Q14_Part_11                          String
# 57   Q14_OTHER_TEXT                       String
# 58   Q15_Part_1                           String
# 59   Q15_Part_2                           String
# 60   Q15_Part_3                           String
# 61   Q15_Part_4                           String
# 62   Q15_Part_5                           String
# 63   Q15_Part_6                           String
# 64   Q15_Part_7                           String
# 65   Q15_OTHER_TEXT                       String
# 66   Q16_Part_1                           String
# 67   Q16_Part_2                           String
# 68   Q16_Part_3                           String
# 69   Q16_Part_4                           String
# 70   Q16_Part_5                           String
# 71   Q16_Part_6                           String
# 72   Q16_Part_7                           String
# 73   Q16_Part_8                           String
# 74   Q16_Part_9                           String
# 75   Q16_Part_10                          String
# 76   Q16_Part_11                          String
# 77   Q16_Part_12                          String
# 78   Q16_Part_13                          String
# 79   Q16_Part_14                          String
# 80   Q16_Part_15                          String
# 81   Q16_Part_16                          String
# 82   Q16_Part_17                          String
# 83   Q16_Part_18                          String
# 84   Q16_OTHER_TEXT                       String
# 85   Q17                                  String
# 86   Q17_OTHER_TEXT                       String
# 87   Q18                                  String
# 88   Q18_OTHER_TEXT                       String
# 89   Q19_Part_1                           String
# 90   Q19_Part_2                           String
# 91   Q19_Part_3                           String
# 92   Q19_Part_4                           String
# 93   Q19_Part_5                           String
# 94   Q19_Part_6                           String
# 95   Q19_Part_7                           String
# 96   Q19_Part_8                           String
# 97   Q19_Part_9                           String
# 98   Q19_Part_10                          String
# 99   Q19_Part_11                          String
# 100  Q19_Part_12                          String
# 101  Q19_Part_13                          String
# 102  Q19_Part_14                          String
# 103  Q19_Part_15                          String
# 104  Q19_Part_16                          String
# 105  Q19_Part_17                          String
# 106  Q19_Part_18                          String
# 107  Q19_Part_19                          String
# 108  Q19_OTHER_TEXT                       String
# 109  Q20                                  String
# 110  Q20_OTHER_TEXT                       String
# 111  Q21_Part_1                           String
# 112  Q21_Part_2                           String
# 113  Q21_Part_3                           String
# 114  Q21_Part_4                           String
# 115  Q21_Part_5                           String
# 116  Q21_Part_6                           String
# 117  Q21_Part_7                           String
# 118  Q21_Part_8                           String
# 119  Q21_Part_9                           String
# 120  Q21_Part_10                          String
# 121  Q21_Part_11                          String
# 122  Q21_Part_12                          String
# 123  Q21_Part_13                          String
# 124  Q21_OTHER_TEXT                       String
# 125  Q22                                  String
# 126  Q22_OTHER_TEXT                       String
# 127  Q23                                  String
# 128  Q24                                  String
# 129  Q25                                  String
# 130  Q26                                  String
# 131  Q27_Part_1                           String
# 132  Q27_Part_2                           String
# 133  Q27_Part_3                           String
# 134  Q27_Part_4                           String
# 135  Q27_Part_5                           String
# 136  Q27_Part_6                           String
# 137  Q27_Part_7                           String
# 138  Q27_Part_8                           String
# 139  Q27_Part_9                           String
# 140  Q27_Part_10                          String
# 141  Q27_Part_11                          String
# 142  Q27_Part_12                          String
# 143  Q27_Part_13                          String
# 144  Q27_Part_14                          String
# 145  Q27_Part_15                          String
# 146  Q27_Part_16                          String
# 147  Q27_Part_17                          String
# 148  Q27_Part_18                          String
# 149  Q27_Part_19                          String
# 150  Q27_Part_20                          String
# 151  Q27_OTHER_TEXT                       String
# 152  Q28_Part_1                           String
# 153  Q28_Part_2                           String
# 154  Q28_Part_3                           String
# 155  Q28_Part_4                           String
# 156  Q28_Part_5                           String
# 157  Q28_Part_6                           String
# 158  Q28_Part_7                           String
# 159  Q28_Part_8                           String
# 160  Q28_Part_9                           String
# 161  Q28_Part_10                          String
# 162  Q28_Part_11                          String
# 163  Q28_Part_12                          String
# 164  Q28_Part_13                          String
# 165  Q28_Part_14                          String
# 166  Q28_Part_15                          String
# 167  Q28_Part_16                          String
# 168  Q28_Part_17                          String
# 169  Q28_Part_18                          String
# 170  Q28_Part_19                          String
# 171  Q28_Part_20                          String
# 172  Q28_Part_21                          String
# 173  Q28_Part_22                          String
# 174  Q28_Part_23                          String
# 175  Q28_Part_24                          String
# 176  Q28_Part_25                          String
# 177  Q28_Part_26                          String
# 178  Q28_Part_27                          String
# 179  Q28_Part_28                          String
# 180  Q28_Part_29                          String
# 181  Q28_Part_30                          String
# 182  Q28_Part_31                          String
# 183  Q28_Part_32                          String
# 184  Q28_Part_33                          String
# 185  Q28_Part_34                          String
# 186  Q28_Part_35                          String
# 187  Q28_Part_36                          String
# 188  Q28_Part_37                          String
# 189  Q28_Part_38                          String
# 190  Q28_Part_39                          String
# 191  Q28_Part_40                          String
# 192  Q28_Part_41                          String
# 193  Q28_Part_42                          String
# 194  Q28_Part_43                          String
# 195  Q28_OTHER_TEXT                       String
# 196  Q29_Part_1                           String
# 197  Q29_Part_2                           String
# 198  Q29_Part_3                           String
# 199  Q29_Part_4                           String
# 200  Q29_Part_5                           String
# 201  Q29_Part_6                           String
# 202  Q29_Part_7                           String
# 203  Q29_Part_8                           String
# 204  Q29_Part_9                           String
# 205  Q29_Part_10                          String
# 206  Q29_Part_11                          String
# 207  Q29_Part_12                          String
# 208  Q29_Part_13                          String
# 209  Q29_Part_14                          String
# 210  Q29_Part_15                          String
# 211  Q29_Part_16                          String
# 212  Q29_Part_17                          String
# 213  Q29_Part_18                          String
# 214  Q29_Part_19                          String
# 215  Q29_Part_20                          String
# 216  Q29_Part_21                          String
# 217  Q29_Part_22                          String
# 218  Q29_Part_23                          String
# 219  Q29_Part_24                          String
# 220  Q29_Part_25                          String
# 221  Q29_Part_26                          String
# 222  Q29_Part_27                          String
# 223  Q29_Part_28                          String
# 224  Q29_OTHER_TEXT                       String
# 225  Q30_Part_1                           String
# 226  Q30_Part_2                           String
# 227  Q30_Part_3                           String
# 228  Q30_Part_4                           String
# 229  Q30_Part_5                           String
# 230  Q30_Part_6                           String
# 231  Q30_Part_7                           String
# 232  Q30_Part_8                           String
# 233  Q30_Part_9                           String
# 234  Q30_Part_10                          String
# 235  Q30_Part_11                          String
# 236  Q30_Part_12                          String
# 237  Q30_Part_13                          String
# 238  Q30_Part_14                          String
# 239  Q30_Part_15                          String
# 240  Q30_Part_16                          String
# 241  Q30_Part_17                          String
# 242  Q30_Part_18                          String
# 243  Q30_Part_19                          String
# 244  Q30_Part_20                          String
# 245  Q30_Part_21                          String
# 246  Q30_Part_22                          String
# 247  Q30_Part_23                          String
# 248  Q30_Part_24                          String
# 249  Q30_Part_25                          String
# 250  Q30_OTHER_TEXT                       String
# 251  Q31_Part_1                           String
# 252  Q31_Part_2                           String
# 253  Q31_Part_3                           String
# 254  Q31_Part_4                           String
# 255  Q31_Part_5                           String
# 256  Q31_Part_6                           String
# 257  Q31_Part_7                           String
# 258  Q31_Part_8                           String
# 259  Q31_Part_9                           String
# 260  Q31_Part_10                          String
# 261  Q31_Part_11                          String
# 262  Q31_Part_12                          String
# 263  Q31_OTHER_TEXT                       String
# 264  Q32                                  String
# 265  Q32_OTHER                            String
# 266  Q33_Part_1                           String
# 267  Q33_Part_2                           String
# 268  Q33_Part_3                           String
# 269  Q33_Part_4                           String
# 270  Q33_Part_5                           String
# 271  Q33_Part_6                           String
# 272  Q33_Part_7                           String
# 273  Q33_Part_8                           String
# 274  Q33_Part_9                           String
# 275  Q33_Part_10                          String
# 276  Q33_Part_11                          String
# 277  Q33_OTHER_TEXT                       String
# 278  Q34_Part_1                           String
# 279  Q34_Part_2                           String
# 280  Q34_Part_3                           String
# 281  Q34_Part_4                           String
# 282  Q34_Part_5                           String
# 283  Q34_Part_6                           String
# 284  Q34_OTHER_TEXT                       String
# 285  Q35_Part_1                           String
# 286  Q35_Part_2                           String
# 287  Q35_Part_3                           String
# 288  Q35_Part_4                           String
# 289  Q35_Part_5                           String
# 290  Q35_Part_6                           String
# 291  Q35_OTHER_TEXT                       String
# 292  Q36_Part_1                           String
# 293  Q36_Part_2                           String
# 294  Q36_Part_3                           String
# 295  Q36_Part_4                           String
# 296  Q36_Part_5                           String
# 297  Q36_Part_6                           String
# 298  Q36_Part_7                           String
# 299  Q36_Part_8                           String
# 300  Q36_Part_9                           String
# 301  Q36_Part_10                          String
# 302  Q36_Part_11                          String
# 303  Q36_Part_12                          String
# 304  Q36_Part_13                          String
# 305  Q36_OTHER_TEXT                       String
# 306  Q37                                  String
# 307  Q37_OTHER_TEXT                       String
# 308  Q38_Part_1                           String
# 309  Q38_Part_2                           String
# 310  Q38_Part_3                           String
# 311  Q38_Part_4                           String
# 312  Q38_Part_5                           String
# 313  Q38_Part_6                           String
# 314  Q38_Part_7                           String
# 315  Q38_Part_8                           String
# 316  Q38_Part_9                           String
# 317  Q38_Part_10                          String
# 318  Q38_Part_11                          String
# 319  Q38_Part_12                          String
# 320  Q38_Part_13                          String
# 321  Q38_Part_14                          String
# 322  Q38_Part_15                          String
# 323  Q38_Part_16                          String
# 324  Q38_Part_17                          String
# 325  Q38_Part_18                          String
# 326  Q38_Part_19                          String
# 327  Q38_Part_20                          String
# 328  Q38_Part_21                          String
# 329  Q38_Part_22                          String
# 330  Q38_OTHER_TEXT                       String
# 331  Q39_Part_1                           String
# 332  Q39_Part_2                           String
# 333  Q40                                  String
# 334  Q41_Part_1                           String
# 335  Q41_Part_2                           String
# 336  Q41_Part_3                           String
# 337  Q42_Part_1                           String
# 338  Q42_Part_2                           String
# 339  Q42_Part_3                           String
# 340  Q42_Part_4                           String
# 341  Q42_Part_5                           String
# 342  Q42_OTHER_TEXT                       String
# 343  Q43                                  String
# 344  Q44_Part_1                           String
# 345  Q44_Part_2                           String
# 346  Q44_Part_3                           String
# 347  Q44_Part_4                           String
# 348  Q44_Part_5                           String
# 349  Q44_Part_6                           String
# 350  Q45_Part_1                           String
# 351  Q45_Part_2                           String
# 352  Q45_Part_3                           String
# 353  Q45_Part_4                           String
# 354  Q45_Part_5                           String
# 355  Q45_Part_6                           String
# 356  Q46                                  String
# 357  Q47_Part_1                           String
# 358  Q47_Part_2                           String
# 359  Q47_Part_3                           String
# 360  Q47_Part_4                           String
# 361  Q47_Part_5                           String
# 362  Q47_Part_6                           String
# 363  Q47_Part_7                           String
# 364  Q47_Part_8                           String
# 365  Q47_Part_9                           String
# 366  Q47_Part_10                          String
# 367  Q47_Part_11                          String
# 368  Q47_Part_12                          String
# 369  Q47_Part_13                          String
# 370  Q47_Part_14                          String
# 371  Q47_Part_15                          String
# 372  Q47_Part_16                          String
# 373  Q48                                  String
# 374  Q49_Part_1                           String
# 375  Q49_Part_2                           String
# 376  Q49_Part_3                           String
# 377  Q49_Part_4                           String
# 378  Q49_Part_5                           String
# 379  Q49_Part_6                           String
# 380  Q49_Part_7                           String
# 381  Q49_Part_8                           String
# 382  Q49_Part_9                           String
# 383  Q49_Part_10                          String
# 384  Q49_Part_11                          String
# 385  Q49_Part_12                          String
# 386  Q49_OTHER_TEXT                       String
# 387  Q50_Part_1                           String
# 388  Q50_Part_2                           String
# 389  Q50_Part_3                           String
# 390  Q50_Part_4                           String
# 391  Q50_Part_5                           String
# 392  Q50_Part_6                           String
# 393  Q50_Part_7                           String
# 394  Q50_Part_8                           String
# 395  Q50_OTHER_TEXT                       String

# %%
survey_data |> 
    describe
# Out:
# 395×7 DataFrame
#  Row │ variable                           mean     min        median   max     ⋯
#      │ Symbol                             Nothing  String     Nothing  String  ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Time from Start to Finish (secon…           100                 9992    ⋯
#    2 │ Q1                                          Female              Prefer
#    3 │ Q1_OTHER_TEXT                               -1                  9
#    4 │ Q2                                          18-21               80+
#    5 │ Q3                                          Argentina           Viet Na ⋯
#    6 │ Q4                                                              Some co
#    7 │ Q5                                                              Social
#    8 │ Q6                                                              Student
#    9 │ Q6_OTHER_TEXT                               -1                  99      ⋯
#   10 │ Q7                                                              Shippin
#   11 │ Q7_OTHER_TEXT                               -1                  99
#   ⋮  │                 ⋮                     ⋮         ⋮         ⋮             ⋱
#  386 │ Q49_OTHER_TEXT                              -1                  99
#  387 │ Q50_Part_1                                                      Too exp ⋯
#  388 │ Q50_Part_2                                                      Too tim
#  389 │ Q50_Part_3                                                      Require
#  390 │ Q50_Part_4                                                      Afraid
#  391 │ Q50_Part_5                                                      Not eno ⋯
#  392 │ Q50_Part_6                                                      I had n
#  393 │ Q50_Part_7                                                      None of
#  394 │ Q50_Part_8                                                      Other
#  395 │ Q50_OTHER_TEXT                              -1                  99      ⋯
#                                                   3 columns and 374 rows omitted

# %%
survey_data_clean = survey_data |>
    @rename(:Q1 => :gender,
            :Q2 => :age,
            :Q3 => :country,
            :Q4 => :education_level,
            :Q5 => :education_major,
            :Q6 => :job_role,
            :Q7 => :job_industry,
            :Q8 => :job_experience_years,
            :Q9 => :job_salary,
            :Q17 => :job_most_used_language,
            :Q23 => :job_percent_time_coding,
            :Q26 => :job_is_data_scientist) |>
    @select(-occursin("seconds"), 
            -occursin("Q")) |>
    # Could be done with less typing by using joins
    @mutate(age = 
             _.age == "18-21" ? 19.5 :
             _.age == "22-24" ? 23.0 :
             _.age == "25-29" ? 27.0 :
             _.age == "30-34" ? 32.0 :
             _.age == "35-39" ? 37.0 :
             _.age == "40-44" ? 42.0 :
             _.age == "45-49" ? 47.0 :
             _.age == "50-54" ? 52.0 :
             _.age == "55-59" ? 57.0 :
             _.age == "60-69" ? 64.5 :
             _.age == "70-79" ? 74.5 :
             _.age == "80+" ? 90 : NA,
            job_experience_years = 
            _.job_experience_years == "0-1" ? 0.5 :
            _.job_experience_years == "1-2" ? 1.5 :
            _.job_experience_years == "2-3" ? 2.5 :
            _.job_experience_years == "3-4" ? 3.5 :
            _.job_experience_years == "4-5" ? 4.5 :
            _.job_experience_years == "5-10" ? 7.5 :
            _.job_experience_years == "10-15" ? 12.5 :
            _.job_experience_years == "15-20" ? 17.5 :
            _.job_experience_years == "20-25" ? 22.5 :
            _.job_experience_years == "25-30" ? 27.5 :
            _.job_experience_years == "30 +" ? 40 : NA,
            job_salary = 
            _.job_salary == "0-10,000" ? 5_000 :
            _.job_salary == "10-20,000" ? 15_000 :
            _.job_salary == "20-30,000" ? 25_000 :
            _.job_salary == "30-40,000" ? 35_000 :
            _.job_salary == "40-50,000" ? 45_000 :
            _.job_salary == "50-60,000" ? 55_000 :
            _.job_salary == "60-70,000" ? 65_000 :
            _.job_salary == "70-80,000" ? 75_000 :
            _.job_salary == "80-90,000" ? 85_000 :
            _.job_salary == "90-100,000" ? 95_000 :
            _.job_salary == "100-125,000" ? 112_500 :
            _.job_salary == "125-150,000" ? 137_500 :
            _.job_salary == "150-200,000" ? 175_000 :
            _.job_salary == "200-250,000" ? 225_000 :
            _.job_salary == "250-300,000" ? 275_000 :
            _.job_salary == "300-400,000" ? 350_000 :
            _.job_salary == "400-500,000" ? 450_000 :
            _.job_salary == "500,000+" ? 500_000 : NA,
            job_percent_time_coding =
            _.job_percent_time_coding == "0% of my time" ? 0 :
            _.job_percent_time_coding == "1% to 25% of my time" ? 13 :
            _.job_percent_time_coding == "25% to 49% of my time" ? 37 :
            _.job_percent_time_coding == "50% to 74% of my time" ? 62 :
            _.job_percent_time_coding == "75% to 99% of my time" ? 87 :
            _.job_percent_time_coding == "100% of my time" ? 100 : NA) |>
  @dropna() |>
  @mutate(age = Float64(_.age),
          job_experience_years = Float64(_.job_experience_years),
          job_salary = Float64(_.job_salary),
          job_percent_time_coding = Float64(_.job_percent_time_coding) / 100) |>
  DataFrame
# Out:
# 13399×12 DataFrame
#    Row │ gender             age   country                            education ⋯
#        │ Any                Any   Any                                Any       ⋯
# ───────┼────────────────────────────────────────────────────────────────────────
#      1 │ Male               32.0  Indonesia                          Bachelor’ ⋯
#      2 │ Female             32.0  United States of America           Master’s
#      3 │ Male               23.0  India                              Master’s
#      4 │ Male               37.0  Chile                              Doctoral
#      5 │ Male               19.5  India                              Master’s  ⋯
#      6 │ Male               32.0  Hungary                            Master’s
#      7 │ Male               42.0  United States of America           Master’s
#      8 │ Male               27.0  United States of America           Bachelor’
#      9 │ Female             27.0  Argentina                          Bachelor’ ⋯
#     10 │ Male               27.0  Japan                              Master’s
#     11 │ Male               42.0  Colombia                           Master’s
#    ⋮   │         ⋮           ⋮                    ⋮                            ⋱
#  13390 │ Male               32.0  India                              Master’s
#  13391 │ Male               42.0  Ukraine                            Master’s  ⋯
#  13392 │ Male               27.0  Pakistan                           Bachelor’
#  13393 │ Male               37.0  United Kingdom of Great Britain …  Doctoral
#  13394 │ Male               19.5  Turkey                             Bachelor’
#  13395 │ Male               27.0  Russia                             Master’s  ⋯
#  13396 │ Female             23.0  India                              Master’s
#  13397 │ Male               19.5  Russia                             Master’s
#  13398 │ Male               32.0  Netherlands                        Master’s
#  13399 │ Male               47.0  France                             Doctoral  ⋯
#                                                 9 columns and 13378 rows omitted

# %%
survey_data_clean |> 
    describe |> 
    @select(-:min, -:median, -:max)
# Out:
# 12x4 query result
# variable                │ mean    │ nmissing │ eltype
# ────────────────────────┼─────────┼──────────┼───────
# :gender                 │ nothing │ 0        │ Any
# :age                    │ 31.3967 │ 0        │ Any
# :country                │ nothing │ 0        │ Any
# :education_level        │ nothing │ 0        │ Any
# :education_major        │ nothing │ 0        │ Any
# :job_role               │ nothing │ 0        │ Any
# :job_industry           │ nothing │ 0        │ Any
# :job_experience_years   │ 4.99798 │ 0        │ Any
# :job_salary             │ 51978.3 │ 0        │ Any
# :job_most_used_language │ nothing │ 0        │ Any
# ... with 2 more rows

# %%
survey_data_clean |> 
    describe |> 
    @select(:variable, :min, :median, :max)
# Out:
# 12x4 query result
# variable                │ min                   │ median
# ────────────────────────┼───────────────────────┼────────
# :gender                 │ "Female"              │ nothing
# :age                    │ 19.5                  │ 27.0
# :country                │ "Argentina"           │ nothing
# :education_level        │ "Bachelor’s degree"   │ nothing
# :education_major        │ ""                    │ nothing
# :job_role               │ "Business Analyst"    │ nothing
# :job_industry           │ "Academics/Education" │ nothing
# :job_experience_years   │ 0.5                   │ 2.5
# :job_salary             │ 5000.0                │ 35000.0
# :job_most_used_language │ ""                    │ nothing
# ... with 2 more rows, and 1 more column: max

# %%
names(survey_data_clean)
# Out:
# 12-element Vector{String}:
#  "gender"
#  "age"
#  "country"
#  "education_level"
#  "education_major"
#  "job_role"
#  "job_industry"
#  "job_experience_years"
#  "job_salary"
#  "job_most_used_language"
#  "job_percent_time_coding"
#  "job_is_data_scientist"

# %%
survey_data_clean |>
  size
# Out:
# (13399, 12)

# %%
# No NAs
survey_data_clean |> 
  @dropna() |> 
  DataFrame |> 
  size
# Out:
# (13399, 12)
